# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\soumy\Downloads\modern-optics-449413-t5-d44f372c3ce2.json"

# %%
import sys
# !{sys.executable} -m pip install google-cloud-bigquery

# %%
import sys
# !{sys.executable} -m pip install db-dtypes
# Out:
# ...
#   Obtaining dependency information for db-dtypes from https://files.pythonhosted.org/packages/69/aa/8f09c6af64d562606d128acab327dab759ac005a204f470c6d257f47d857/db_dtypes-1.4.2-py2.py3-none-any.whl.metadata
# ...

# %%
from google.cloud import bigquery

# Initialize the client with the service account credentials
client = bigquery.Client()

# %%
query = """
SELECT * FROM `modern-optics-449413-t5.marketing_test.customer_purchase_data`
LIMIT 100
"""

# Run the query and load it into a DataFrame
df = client.query(query).to_dataframe()
df.head()
# Out:
# C:\Users\soumy\Downloads\ana\Lib\site-packages\google\cloud\bigquery\table.py:1933: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   18       1  149785.176481                 10                0
# 1   18       0   42734.586833                 12                0
# 2   18       1   87934.957914                  6                0
# 3   18       0   46262.036892                 19                0
# 4   18       0   47643.768928                 15                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           38.979469               0                 5               1
# 1           56.137874               0                 0               0
# 2           59.968606               1                 4               1
# 3           32.655011               0                 5               1
# ...

# %%
import pandas as pd


csv_file_path = r"C:\Users\soumy\Downloads\zara.csv" #path file, raw string when backlash
df = pd.read_csv(csv_file_path, delimiter=';') # reading the file

# Save the DataFrame as an Excel file
df.to_excel(file_path, index=False)

print(f"Data saved to {file_path}")
# Out:
# Data saved to C:\Users\soumy\Downloads\zara.xlsx

# %%
import pandas as pd

data={
    
    'name': ['Soumya','Athul'],
    'age':[27,31]
    }

df=pd.DataFrame(data)
df
# Out:
#      name  age
# 0  Soumya   27
# 1   Athul   31

# %%
print(pd.options.display.max_rows) # to print max. number of rows that pandas can display
pd.options.display.max_rows = 100
# Out:
# 60

# %%
df=pd.read_json(r"C:\Users\soumy\Downloads\sample_users_with_id.json") #read json files
print(df.to_string())
# Out:
#                     user_id              email            name given_name family_name nickname        last_ip  logins_count                       created_at                       updated_at                last_login  email_verified
# 0  583c3ac3f38e84297c002546      test@test.com   test@test.com      Hello        Test     test  94.121.163.63          15.0 2016-11-28 14:10:11.338000+00:00 2016-12-02 01:17:29.310000+00:00  2016-12-02T01:17:29.310Z            True
# 1  583c5484cb79a5fe593425a9     test1@test.com  test1@test.com     Hello1       Test1    test1  94.121.168.53           1.0 2016-11-28 16:00:04.209000+00:00 2016-11-28 16:00:47.203000+00:00  2016-11-28T16:00:47.203Z            True
# 2  583c57672c7686377d2f66c9        aaa@aaa.com     aaa@aaa.com       John       Dough      aaa  94.121.168.53           2.0 2016-11-28 16:12:23.777000+00:00 2016-11-28 16:12:52.353000+00:00  2016-11-28T16:12:52.353Z            True
# ...

# %%
import pandas as pd
csv_file_path = r"C:\Users\soumy\Downloads\zara.csv" #path file, raw string when backlash
df = pd.read_csv(csv_file_path, delimiter=';') # reading the file
df.head(10)
#df.info()
# Out:
#    Product ID Product Position Promotion Product Category Seasonal  \
# 0      185102            Aisle        No         Clothing       No
# 1      188771            Aisle        No         Clothing       No
# 2      180176          End-cap       Yes         Clothing      Yes
# 3      112917            Aisle       Yes         Clothing      Yes
# 4      192936          End-cap        No         Clothing      Yes
# 5      117590          End-cap        No         Clothing       No
# 6      189118   Front of Store       Yes         Clothing      Yes
# 7      182157            Aisle        No         Clothing       No
# 8      141861            Aisle       Yes         Clothing      Yes
# 9      137121            Aisle        No         Clothing      Yes
#
#    Sales Volume brand                                                url  \
# 0          2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1           654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# ...

# %%
#exploring the data

df.shape
df.columns
df.info()
df.describe()
df.dtypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        252 non-null    int64
#  1   Product Position  252 non-null    object
#  2   Promotion         252 non-null    object
#  3   Product Category  252 non-null    object
#  4   Seasonal          252 non-null    object
#  5   Sales Volume      252 non-null    int64
#  6   brand             252 non-null    object
#  7   url               252 non-null    object
#  8   sku               252 non-null    object
#  9   name              251 non-null    object
#  10  description       250 non-null    object
#  11  price             252 non-null    float64
#  12  currency          252 non-null    object
#  13  scraped_at        252 non-null    datetime64[ns]
#  14  terms             252 non-null    object
#  15  section           252 non-null    object
# ...

# %%
#Clean the data
df.isnull().sum() #check for nulls
df.head(10)
df[df['name'].isnull()] # check for the nulls

df['scraped_at']=pd.to_datetime(df['scraped_at']) #converting the datatypes
df['price']=pd.to_numeric(df['price'])

# %%
df.head(10)

# %%
#what is the sales volume across all the products

df['Sales Volume'].sum()
# Out:
# 459573

# %%
df.rename(columns={'name':'product_name','description':'product_descrption'})
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
# 249      137044            Aisle        No         Clothing      Yes
# 250      154736   Front of Store       Yes         Clothing      Yes
# 251      141434   Front of Store        No         Clothing      Yes
#
#      Sales Volume brand                                                url  \
# ...

# %%
df[df['price'] == df['price'].max()]
# Out:
#     Product ID Product Position Promotion Product Category Seasonal  \
# 13      151396   Front of Store       Yes         Clothing      Yes
#
#     Sales Volume brand                                                url  \
# 13           729  Zara  https://www.zara.com/us/en/cropped-leather-jac...
#
#                 sku                    name  \
# 13  323134418-800-3  CROPPED LEATHER JACKET
#
#                                           description  price currency  \
# 13  Leather jacket. Cropped length. Lapel collar a...  439.0      USD
#
#                    scraped_at    terms section
# 13 2024-02-19 08:50:13.771115  jackets     MAN

# %%
df['Product Category'].unique()
# Out:
# array(['Clothing'], dtype=object)

# %%
df['brand'].value_counts().idxmax()
# Out:
# 'Zara'

# %%
df[df['Product Category']=='Clothing']['price'].mean().round()
# Out:
# 86.0

# %%
df.groupby('Product Position')['Sales Volume'].sum().idxmax()
# Out:
# 'Aisle'

# %%
df[df['Promotion']=='Yes'].shape[0]
# Out:
# 120

# %%
df['Seasonal'].value_counts().idxmax()
# Out:
# 'Yes'

# %%
df['sku'].nunique()
# Out:
# 228

# %%
df[df['currency']=='USD']['price'].mean().round(2)
# Out:
# 86.25

# %%
#Popular methods

#exploration
'''
df.head() #gives first rows
df.tail() #gives last rows
df.describe() #summary of stats for numeric columns
df.shape #number of rows and columns
df.columns #columns
df.info() #columns, non null values, data type
df.isnull().sum() #count of missing values per column

#cleaning

#df.dropna()  #drop rows with null values
#df.fillna(value) #fill null values with value given
#df.rename(columns={'old':'new'}) 

df.duplicated('Product Position')

df.drop_duplicates()


df.info()
'''
df['scraped_at']=pd.to_datetime(df['scraped_at'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        252 non-null    int64
#  1   Product Position  252 non-null    object
#  2   Promotion         252 non-null    object
#  3   Product Category  252 non-null    object
#  4   Seasonal          252 non-null    object
#  5   Sales Volume      252 non-null    int64
#  6   brand             252 non-null    object
#  7   url               252 non-null    object
#  8   sku               252 non-null    object
#  9   name              251 non-null    object
#  10  description       250 non-null    object
#  11  price             252 non-null    float64
#  12  currency          252 non-null    object
#  13  scraped_at        252 non-null    datetime64[ns]
#  14  terms             252 non-null    object
#  15  section           252 non-null    object
# ...

# %%
#data filtering & Selection

#df['url'] #selecting one column

df[['url','Product ID']] #Selecting 2 columns

df.loc[df['Product ID']==185102] # selecting a row with a value


df[df['scraped_at'] >'2024-02-19'] # where condition
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
# 249      137044            Aisle        No         Clothing      Yes
# 250      154736   Front of Store       Yes         Clothing      Yes
# 251      141434   Front of Store        No         Clothing      Yes
#
#      Sales Volume brand                                                url  \
# ...

# %%
#aggregation and grouping

df.groupby(df['Product Position']).price.mean().round
# Out:
# <bound method Series.round of Product Position
# Aisle             88.785773
# End-cap           81.276395
# Front of Store    88.893478
# Name: price, dtype: float64>

# %%
#df.groupby('Product Position')['Sales Volume'].sum()

df.rename(columns={'name':'product_name'})
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
# 249      137044            Aisle        No         Clothing      Yes
# 250      154736   Front of Store       Yes         Clothing      Yes
# 251      141434   Front of Store        No         Clothing      Yes
#
#      Sales Volume brand                                                url  \
# ...

# %%
df.groupby('name')['Sales Volume'].sum().sort_values(ascending=False).head(5)
# Out:
# name
# PLAID OVERSHIRT                      10910
# POCKET OVERSHIRT                      7386
# FAUX LEATHER BOMBER JACKET            7197
# FAUX LEATHER JACKET                   7113
# CONTRASTING PATCHES BOMBER JACKET     7050
# Name: Sales Volume, dtype: int64
